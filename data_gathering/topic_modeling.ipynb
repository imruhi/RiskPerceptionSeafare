# %%
from bertopic import BERTopic
from datasets import Dataset

# %%
data_path = f'/home/imruhi/Documents/RiskPerceptionSeafare/data_gathering/data/roberta_data_25_filtered'
topic_model_path = "topic_model1"

# %%
topic_model = BERTopic.load(topic_model_path)
# Out:
# 2026-04-20 15:09:30,396 - BERTopic - WARNING: You are loading a BERTopic model without explicitly defining an embedding model. If you want to also load in an embedding model, make sure to use `BERTopic.load(my_model, embedding_model=my_embedding_model)`.

# %%
topic_model.visualize_topics()

# %%
topic_model.topic_labels_
# Out:
# {-1: '-1_miles_harbor_30_00',
#  0: '0_ship_harbour_port_shores',
#  1: '1_att_atticus_ship_letter',
#  2: '2_δὲ_ὡς_ἐν_ἀπὸ'}

# %%
topic_model.get_topic_freq(0)
# Out:
# 22009

# %%
df = Dataset.load_from_disk(data_path).to_pandas()

# %%
df[df["topic"]==0]["text"][0]
# Out:
# 'above these places are the Bebrykes. Then along the sea below are the Ligurians and Greek cities which the Phokaian Massaliotes colonized. First Emporion, second Rhode; this one the Rhodians, powerful in ships, had founded before. Coming after them into Iberia the Phokaian founders of Massalia held it, and Agathe and'
